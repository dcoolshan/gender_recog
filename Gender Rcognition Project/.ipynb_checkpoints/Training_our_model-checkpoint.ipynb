# %%
import torch 
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import utils
import numpy as np
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

data = pd.read_csv('voice.csv') #loading data using panda 
male_data=data[data['label']=='male'] #partitioning male data from our original data voice.csv
female_data=data[data['label']=='female'] #partitioning female data from our original data voice.csv
male_data.loc[:,'label']=1  #converting label male to 1
male_data.iloc[:,:-1]=((male_data.iloc[:,:-1]-male_data.iloc[:,:-1].min())/(male_data.iloc[:,:-1].max()-male_data.iloc[:,:-1].min()))
female_data.loc[:,'label']=0 #converting label female to 0
female_data.iloc[:,:-1]=((female_data.iloc[:,:-1]-female_data.iloc[:,:-1].min())/(female_data.iloc[:,:-1].max()-female_data.iloc[:,:-1].min()))
data_with_label_1_0=pd.concat([male_data,female_data]) #combining male and female data again to make complete data again with label 0(female) and 1(male) 
data_with_label_1_0 = data_with_label_1_0.sample(frac=1).reset_index(drop=True) #shuffling our data randomly
size_of_data=data_with_label_1_0.shape[0] #total size of data
train_data_with_label_1_0=data_with_label_1_0.loc[:size_of_data*8.0/10,:] #taking 80% for train
valid_data_with_label_1_0=data_with_label_1_0.loc[size_of_data*8.0/10:size_of_data*9.0/10,:] #taking 10% for validation
test_data_with_label_1_0=data_with_label_1_0.loc[size_of_data*9.0/10:size_of_data,:] #taking 10% for test

 #converting our data from pandas to tensor
train_data_tensor = torch.tensor(train_data_with_label_1_0.values)
valid_data_tensor = torch.tensor(valid_data_with_label_1_0.values)
test_data_tensor = torch.tensor(test_data_with_label_1_0.values)

#making data loader for all train ,test and valid dataset and making batches for stochastic 
trainloader = torch.utils.data.DataLoader(train_data_tensor, batch_size=32, shuffle=False)
validloader = torch.utils.data.DataLoader(valid_data_tensor, batch_size=317, shuffle=False) # 317 is full size of valid_data_tensor
testloader = torch.utils.data.DataLoader(test_data_tensor, batch_size=316, shuffle=False)  # 316 is full size of test_data_tensor
#basically taking whole batch together for valid and test to speed up process

model = nn.Sequential(nn.Linear(20, 64),
                      nn.ReLU(),
                      nn.Dropout(p=0.25),
                      nn.Linear(64, 256),
                      nn.ReLU(),
                      nn.Dropout(p=0.25),
                      nn.Linear(256, 256),
                      nn.ReLU(),
                      nn.Dropout(p=0.25),
                      nn.Linear(256, 64),
                      nn.ReLU(),
                      nn.Dropout(p=0.25),
                      nn.Linear(64, 1),
                      nn.Sigmoid()
                      ) 
#our model consist of 4 hidden layer one output and one input , 20 units in input,64 in first hidden,256 in second,256 in third,64 in fourth and one unit in output layer 
#and finally passed through sigmoid to get output between 0 and 1 

train_losses, valid_losses,valid_accuracies= [], [], [] #will keep taking/appending values of this for plotting graph in end
criterion = nn.BCELoss() #loss function used is BCE
optimizer = optim.Adam(model.parameters(), lr=0.001) #adam optimizer is used as it prevents local minima convergence
epochs = 80 #no. of epochs decided by observing validation and training graph convergence 
for e in range(epochs):
    running_loss = 0 
    for train_data_with_label in trainloader:   
        train_data=train_data_with_label[:,:-1]
        train_data_label=train_data_with_label[:,-1:]
        optimizer.zero_grad()  #used to remove all previous accumulated values
        
        output = model(train_data.type(torch.FloatTensor)).view(-1) #precdicted value we get from network 
        train_data_label = train_data_label.view(-1)
        #print(output)
        loss = criterion(output,train_data_label.float())
        loss.backward()
        optimizer.step()
        
        running_loss+= loss.item()
    else:
        valid_loss = 0
        valid_accuracy = 0
        
        with torch.no_grad():
            model.eval()
            for valid_data_with_label in validloader:
                valid_data=valid_data_with_label[:,:-1]
                valid_data_label=valid_data_with_label[:,-1:] 
                output_valid = model(valid_data.type(torch.FloatTensor)).view(-1) #precdicted value we get from network 
                #print(output_valid)
                valid_data_label = valid_data_label.view(-1)
                valid_loss += criterion(output_valid,valid_data_label.float())   
                valid_accuracy+=len(np.where(valid_data_label.double()==(output_valid.detach()>0.5).double())[0])
                       #valid_accuracy is total sum of correct prediction divided by total number of example, here we only do sum and down we do division 
        
        model.train()
        valid_accuracy=valid_accuracy/317 #as above we only did the sum of correct examples
        train_losses.append(running_loss/len(trainloader)) #here we keep appending value of training loss after eacch epoch and later is used to make graph
        valid_losses.append(valid_loss/len(validloader))  #here we keep appending value of validation loss after eacch epoch and later is used to make graph
        valid_accuracies.append(valid_accuracy)  #here we keep appending value of validation accuracy after eacch epoch and later is used to make graph
        print("Epoch: {}/{}.. ".format(e+1, epochs),
              "Training Loss: {:.3f}.. ".format(train_losses[-1]),
              "Valid Loss: {:.3f}.. ".format(valid_losses[-1]),
              "Valid Accuracy: {:.3f}.. ".format(valid_accuracy))

        # training and validation complete now model has learnt all weights we require for good accuracy by adam optimizer
plt.plot(train_losses, label='Training loss') #plotting training loss vs no. of epoch
plt.plot(valid_losses, label='Validation loss') #plotting validation loss vs no. of epoch
plt.plot(valid_accuracies, label='Validation Accuracy') #plotting validation accuracy vs no. of epoch
plt.legend(frameon=False)
# Out:
# C:\Users\Saarthak\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Epoch: 1/150..  Training Loss: 0.605..  Valid Loss: 0.258..  Valid Accuracy: 0.927..
# Epoch: 2/150..  Training Loss: 0.258..  Valid Loss: 0.104..  Valid Accuracy: 0.978..
# Epoch: 3/150..  Training Loss: 0.164..  Valid Loss: 0.078..  Valid Accuracy: 0.972..
# Epoch: 4/150..  Training Loss: 0.135..  Valid Loss: 0.060..  Valid Accuracy: 0.984..
# Epoch: 5/150..  Training Loss: 0.114..  Valid Loss: 0.070..  Valid Accuracy: 0.975..
# Epoch: 6/150..  Training Loss: 0.108..  Valid Loss: 0.052..  Valid Accuracy: 0.987..
# Epoch: 7/150..  Training Loss: 0.086..  Valid Loss: 0.047..  Valid Accuracy: 0.984..
# Epoch: 8/150..  Training Loss: 0.079..  Valid Loss: 0.043..  Valid Accuracy: 0.984..
# Epoch: 9/150..  Training Loss: 0.077..  Valid Loss: 0.041..  Valid Accuracy: 0.987..
# Epoch: 10/150..  Training Loss: 0.074..  Valid Loss: 0.046..  Valid Accuracy: 0.984..
# Epoch: 11/150..  Training Loss: 0.061..  Valid Loss: 0.045..  Valid Accuracy: 0.981..
# Epoch: 12/150..  Training Loss: 0.061..  Valid Loss: 0.041..  Valid Accuracy: 0.984..
# Epoch: 13/150..  Training Loss: 0.056..  Valid Loss: 0.037..  Valid Accuracy: 0.987..
# Epoch: 14/150..  Training Loss: 0.046..  Valid Loss: 0.031..  Valid Accuracy: 0.987..
# Epoch: 15/150..  Training Loss: 0.056..  Valid Loss: 0.048..  Valid Accuracy: 0.978..
# Epoch: 16/150..  Training Loss: 0.040..  Valid Loss: 0.032..  Valid Accuracy: 0.991..
# Epoch: 17/150..  Training Loss: 0.046..  Valid Loss: 0.032..  Valid Accuracy: 0.991..
# Epoch: 18/150..  Training Loss: 0.036..  Valid Loss: 0.028..  Valid Accuracy: 0.984..
# Epoch: 19/150..  Training Loss: 0.046..  Valid Loss: 0.028..  Valid Accuracy: 0.987..
# Epoch: 20/150..  Training Loss: 0.044..  Valid Loss: 0.027..  Valid Accuracy: 0.987..
# Epoch: 21/150..  Training Loss: 0.037..  Valid Loss: 0.026..  Valid Accuracy: 0.991..
# Epoch: 22/150..  Training Loss: 0.033..  Valid Loss: 0.031..  Valid Accuracy: 0.981..
# Epoch: 23/150..  Training Loss: 0.033..  Valid Loss: 0.034..  Valid Accuracy: 0.984..
# Epoch: 24/150..  Training Loss: 0.036..  Valid Loss: 0.026..  Valid Accuracy: 0.984..
# Epoch: 25/150..  Training Loss: 0.030..  Valid Loss: 0.029..  Valid Accuracy: 0.984..
# Epoch: 26/150..  Training Loss: 0.033..  Valid Loss: 0.026..  Valid Accuracy: 0.981..
# Epoch: 27/150..  Training Loss: 0.031..  Valid Loss: 0.028..  Valid Accuracy: 0.984..
# Epoch: 28/150..  Training Loss: 0.024..  Valid Loss: 0.029..  Valid Accuracy: 0.984..
# Epoch: 29/150..  Training Loss: 0.038..  Valid Loss: 0.031..  Valid Accuracy: 0.987..
# Epoch: 30/150..  Training Loss: 0.030..  Valid Loss: 0.023..  Valid Accuracy: 0.994..
# Epoch: 31/150..  Training Loss: 0.032..  Valid Loss: 0.026..  Valid Accuracy: 0.991..
# Epoch: 32/150..  Training Loss: 0.029..  Valid Loss: 0.022..  Valid Accuracy: 0.991..
# Epoch: 33/150..  Training Loss: 0.027..  Valid Loss: 0.014..  Valid Accuracy: 0.994..
# Epoch: 34/150..  Training Loss: 0.029..  Valid Loss: 0.029..  Valid Accuracy: 0.987..
# Epoch: 35/150..  Training Loss: 0.025..  Valid Loss: 0.012..  Valid Accuracy: 0.994..
# Epoch: 36/150..  Training Loss: 0.023..  Valid Loss: 0.029..  Valid Accuracy: 0.987..
# Epoch: 37/150..  Training Loss: 0.025..  Valid Loss: 0.036..  Valid Accuracy: 0.987..
# Epoch: 38/150..  Training Loss: 0.024..  Valid Loss: 0.019..  Valid Accuracy: 0.991..
# Epoch: 39/150..  Training Loss: 0.014..  Valid Loss: 0.020..  Valid Accuracy: 0.991..
# Epoch: 40/150..  Training Loss: 0.016..  Valid Loss: 0.020..  Valid Accuracy: 0.991..
# Epoch: 41/150..  Training Loss: 0.015..  Valid Loss: 0.020..  Valid Accuracy: 0.991..
# Epoch: 42/150..  Training Loss: 0.023..  Valid Loss: 0.023..  Valid Accuracy: 0.994..
# Epoch: 43/150..  Training Loss: 0.021..  Valid Loss: 0.064..  Valid Accuracy: 0.978..
# Epoch: 44/150..  Training Loss: 0.019..  Valid Loss: 0.026..  Valid Accuracy: 0.991..
# Epoch: 45/150..  Training Loss: 0.017..  Valid Loss: 0.033..  Valid Accuracy: 0.987..
# Epoch: 46/150..  Training Loss: 0.019..  Valid Loss: 0.029..  Valid Accuracy: 0.994..
# Epoch: 47/150..  Training Loss: 0.023..  Valid Loss: 0.028..  Valid Accuracy: 0.987..
# Epoch: 48/150..  Training Loss: 0.018..  Valid Loss: 0.028..  Valid Accuracy: 0.987..
# Epoch: 49/150..  Training Loss: 0.016..  Valid Loss: 0.029..  Valid Accuracy: 0.994..
# Epoch: 50/150..  Training Loss: 0.009..  Valid Loss: 0.032..  Valid Accuracy: 0.991..
# Epoch: 51/150..  Training Loss: 0.020..  Valid Loss: 0.032..  Valid Accuracy: 0.987..
# Epoch: 52/150..  Training Loss: 0.012..  Valid Loss: 0.026..  Valid Accuracy: 0.987..
# Epoch: 53/150..  Training Loss: 0.024..  Valid Loss: 0.024..  Valid Accuracy: 0.987..
# Epoch: 54/150..  Training Loss: 0.029..  Valid Loss: 0.038..  Valid Accuracy: 0.987..
# Epoch: 55/150..  Training Loss: 0.014..  Valid Loss: 0.029..  Valid Accuracy: 0.994..
# Epoch: 56/150..  Training Loss: 0.014..  Valid Loss: 0.015..  Valid Accuracy: 0.994..
# Epoch: 57/150..  Training Loss: 0.011..  Valid Loss: 0.043..  Valid Accuracy: 0.987..
# Epoch: 58/150..  Training Loss: 0.023..  Valid Loss: 0.025..  Valid Accuracy: 0.994..
# Epoch: 59/150..  Training Loss: 0.020..  Valid Loss: 0.018..  Valid Accuracy: 0.987..
# Epoch: 60/150..  Training Loss: 0.019..  Valid Loss: 0.022..  Valid Accuracy: 0.994..
# Epoch: 61/150..  Training Loss: 0.012..  Valid Loss: 0.036..  Valid Accuracy: 0.987..
# Epoch: 62/150..  Training Loss: 0.010..  Valid Loss: 0.023..  Valid Accuracy: 0.991..
# Epoch: 63/150..  Training Loss: 0.022..  Valid Loss: 0.019..  Valid Accuracy: 0.997..
# Epoch: 64/150..  Training Loss: 0.014..  Valid Loss: 0.022..  Valid Accuracy: 0.994..
# Epoch: 65/150..  Training Loss: 0.009..  Valid Loss: 0.054..  Valid Accuracy: 0.987..
# Epoch: 66/150..  Training Loss: 0.025..  Valid Loss: 0.045..  Valid Accuracy: 0.984..
# Epoch: 67/150..  Training Loss: 0.016..  Valid Loss: 0.033..  Valid Accuracy: 0.987..
# Epoch: 68/150..  Training Loss: 0.008..  Valid Loss: 0.013..  Valid Accuracy: 0.997..
# Epoch: 69/150..  Training Loss: 0.008..  Valid Loss: 0.010..  Valid Accuracy: 0.994..
# Epoch: 70/150..  Training Loss: 0.014..  Valid Loss: 0.004..  Valid Accuracy: 1.000..
# Epoch: 71/150..  Training Loss: 0.012..  Valid Loss: 0.025..  Valid Accuracy: 0.997..
# Epoch: 72/150..  Training Loss: 0.013..  Valid Loss: 0.021..  Valid Accuracy: 0.987..
# Epoch: 73/150..  Training Loss: 0.016..  Valid Loss: 0.016..  Valid Accuracy: 0.994..
# Epoch: 74/150..  Training Loss: 0.009..  Valid Loss: 0.036..  Valid Accuracy: 0.984..
# Epoch: 75/150..  Training Loss: 0.018..  Valid Loss: 0.018..  Valid Accuracy: 0.994..
# Epoch: 76/150..  Training Loss: 0.009..  Valid Loss: 0.048..  Valid Accuracy: 0.984..
# Epoch: 77/150..  Training Loss: 0.014..  Valid Loss: 0.017..  Valid Accuracy: 0.997..
# Epoch: 78/150..  Training Loss: 0.010..  Valid Loss: 0.039..  Valid Accuracy: 0.991..
# Epoch: 79/150..  Training Loss: 0.022..  Valid Loss: 0.042..  Valid Accuracy: 0.991..
# Epoch: 80/150..  Training Loss: 0.019..  Valid Loss: 0.028..  Valid Accuracy: 0.994..
# Epoch: 81/150..  Training Loss: 0.018..  Valid Loss: 0.007..  Valid Accuracy: 0.997..
# Epoch: 82/150..  Training Loss: 0.007..  Valid Loss: 0.017..  Valid Accuracy: 0.997..
# Epoch: 83/150..  Training Loss: 0.016..  Valid Loss: 0.017..  Valid Accuracy: 0.994..
# Epoch: 84/150..  Training Loss: 0.006..  Valid Loss: 0.052..  Valid Accuracy: 0.984..
# Epoch: 85/150..  Training Loss: 0.012..  Valid Loss: 0.022..  Valid Accuracy: 0.997..
# Epoch: 86/150..  Training Loss: 0.021..  Valid Loss: 0.047..  Valid Accuracy: 0.987..
# Epoch: 87/150..  Training Loss: 0.020..  Valid Loss: 0.021..  Valid Accuracy: 0.991..
# Epoch: 88/150..  Training Loss: 0.009..  Valid Loss: 0.045..  Valid Accuracy: 0.987..
# Epoch: 89/150..  Training Loss: 0.009..  Valid Loss: 0.045..  Valid Accuracy: 0.987..
# Epoch: 90/150..  Training Loss: 0.015..  Valid Loss: 0.012..  Valid Accuracy: 0.997..
# Epoch: 91/150..  Training Loss: 0.015..  Valid Loss: 0.011..  Valid Accuracy: 0.997..
# Epoch: 92/150..  Training Loss: 0.009..  Valid Loss: 0.018..  Valid Accuracy: 0.997..
# Epoch: 93/150..  Training Loss: 0.010..  Valid Loss: 0.019..  Valid Accuracy: 0.994..
# Epoch: 94/150..  Training Loss: 0.015..  Valid Loss: 0.017..  Valid Accuracy: 0.994..
# Epoch: 95/150..  Training Loss: 0.014..  Valid Loss: 0.013..  Valid Accuracy: 0.997..
# Epoch: 96/150..  Training Loss: 0.009..  Valid Loss: 0.006..  Valid Accuracy: 0.997..
# Epoch: 97/150..  Training Loss: 0.010..  Valid Loss: 0.011..  Valid Accuracy: 0.991..
# Epoch: 98/150..  Training Loss: 0.010..  Valid Loss: 0.010..  Valid Accuracy: 0.997..
# Epoch: 99/150..  Training Loss: 0.009..  Valid Loss: 0.027..  Valid Accuracy: 0.991..
# Epoch: 100/150..  Training Loss: 0.008..  Valid Loss: 0.023..  Valid Accuracy: 0.994..
# Epoch: 101/150..  Training Loss: 0.012..  Valid Loss: 0.017..  Valid Accuracy: 0.994..
# Epoch: 102/150..  Training Loss: 0.018..  Valid Loss: 0.036..  Valid Accuracy: 0.994..
# Epoch: 103/150..  Training Loss: 0.015..  Valid Loss: 0.008..  Valid Accuracy: 0.997..
# Epoch: 104/150..  Training Loss: 0.008..  Valid Loss: 0.024..  Valid Accuracy: 0.994..
# Epoch: 105/150..  Training Loss: 0.003..  Valid Loss: 0.026..  Valid Accuracy: 0.997..
# Epoch: 106/150..  Training Loss: 0.007..  Valid Loss: 0.023..  Valid Accuracy: 0.997..
# Epoch: 107/150..  Training Loss: 0.015..  Valid Loss: 0.010..  Valid Accuracy: 0.997..
# Epoch: 108/150..  Training Loss: 0.019..  Valid Loss: 0.009..  Valid Accuracy: 0.997..
# Epoch: 109/150..  Training Loss: 0.006..  Valid Loss: 0.013..  Valid Accuracy: 0.994..
# Epoch: 110/150..  Training Loss: 0.010..  Valid Loss: 0.024..  Valid Accuracy: 0.987..
# Epoch: 111/150..  Training Loss: 0.009..  Valid Loss: 0.025..  Valid Accuracy: 0.991..
# Epoch: 112/150..  Training Loss: 0.014..  Valid Loss: 0.017..  Valid Accuracy: 0.997..
# Epoch: 113/150..  Training Loss: 0.009..  Valid Loss: 0.007..  Valid Accuracy: 0.997..
# Epoch: 114/150..  Training Loss: 0.015..  Valid Loss: 0.021..  Valid Accuracy: 0.994..
# Epoch: 115/150..  Training Loss: 0.004..  Valid Loss: 0.020..  Valid Accuracy: 0.994..
# Epoch: 116/150..  Training Loss: 0.004..  Valid Loss: 0.033..  Valid Accuracy: 0.991..
# Epoch: 117/150..  Training Loss: 0.013..  Valid Loss: 0.002..  Valid Accuracy: 1.000..
# Epoch: 118/150..  Training Loss: 0.009..  Valid Loss: 0.013..  Valid Accuracy: 0.997..
# Epoch: 119/150..  Training Loss: 0.009..  Valid Loss: 0.013..  Valid Accuracy: 0.994..
# Epoch: 120/150..  Training Loss: 0.015..  Valid Loss: 0.026..  Valid Accuracy: 0.991..
# Epoch: 121/150..  Training Loss: 0.005..  Valid Loss: 0.003..  Valid Accuracy: 1.000..
# Epoch: 122/150..  Training Loss: 0.008..  Valid Loss: 0.015..  Valid Accuracy: 0.994..
# Epoch: 123/150..  Training Loss: 0.013..  Valid Loss: 0.008..  Valid Accuracy: 0.997..
# Epoch: 124/150..  Training Loss: 0.008..  Valid Loss: 0.017..  Valid Accuracy: 0.997..
# Epoch: 125/150..  Training Loss: 0.006..  Valid Loss: 0.069..  Valid Accuracy: 0.981..
# Epoch: 126/150..  Training Loss: 0.012..  Valid Loss: 0.008..  Valid Accuracy: 0.994..
# Epoch: 127/150..  Training Loss: 0.006..  Valid Loss: 0.007..  Valid Accuracy: 0.997..
# Epoch: 128/150..  Training Loss: 0.016..  Valid Loss: 0.020..  Valid Accuracy: 0.994..
# Epoch: 129/150..  Training Loss: 0.023..  Valid Loss: 0.015..  Valid Accuracy: 0.994..
# Epoch: 130/150..  Training Loss: 0.016..  Valid Loss: 0.010..  Valid Accuracy: 0.991..
# Epoch: 131/150..  Training Loss: 0.006..  Valid Loss: 0.010..  Valid Accuracy: 0.997..
# Epoch: 132/150..  Training Loss: 0.003..  Valid Loss: 0.038..  Valid Accuracy: 0.991..
# Epoch: 133/150..  Training Loss: 0.011..  Valid Loss: 0.016..  Valid Accuracy: 0.994..
# Epoch: 134/150..  Training Loss: 0.008..  Valid Loss: 0.015..  Valid Accuracy: 0.994..
# Epoch: 135/150..  Training Loss: 0.018..  Valid Loss: 0.009..  Valid Accuracy: 0.994..
# Epoch: 136/150..  Training Loss: 0.008..  Valid Loss: 0.012..  Valid Accuracy: 0.994..
# Epoch: 137/150..  Training Loss: 0.005..  Valid Loss: 0.006..  Valid Accuracy: 0.997..
# Epoch: 138/150..  Training Loss: 0.008..  Valid Loss: 0.003..  Valid Accuracy: 1.000..
# Epoch: 139/150..  Training Loss: 0.015..  Valid Loss: 0.020..  Valid Accuracy: 0.987..
# Epoch: 140/150..  Training Loss: 0.007..  Valid Loss: 0.023..  Valid Accuracy: 0.994..
# Epoch: 141/150..  Training Loss: 0.010..  Valid Loss: 0.009..  Valid Accuracy: 0.997..
# Epoch: 142/150..  Training Loss: 0.010..  Valid Loss: 0.015..  Valid Accuracy: 0.994..
# Epoch: 143/150..  Training Loss: 0.007..  Valid Loss: 0.036..  Valid Accuracy: 0.987..
# Epoch: 144/150..  Training Loss: 0.014..  Valid Loss: 0.022..  Valid Accuracy: 0.991..
# Epoch: 145/150..  Training Loss: 0.007..  Valid Loss: 0.006..  Valid Accuracy: 0.997..
# Epoch: 146/150..  Training Loss: 0.004..  Valid Loss: 0.015..  Valid Accuracy: 0.994..
# Epoch: 147/150..  Training Loss: 0.008..  Valid Loss: 0.007..  Valid Accuracy: 0.997..
# Epoch: 148/150..  Training Loss: 0.021..  Valid Loss: 0.023..  Valid Accuracy: 0.991..
# Epoch: 149/150..  Training Loss: 0.009..  Valid Loss: 0.004..  Valid Accuracy: 1.000..
# Epoch: 150/150..  Training Loss: 0.007..  Valid Loss: 0.010..  Valid Accuracy: 0.994..

# %%
test_loss=0
test_accuracy=0
for test_data_with_label in testloader:
    test_data=test_data_with_label[:,:-1]
    #print(test_data_label.shape)
    test_data_label=test_data_with_label[:,-1:] 
    output_test = model(test_data.type(torch.FloatTensor)).view(-1)  #precdicted value we get from network 
        
    test_data_label = test_data_label.view(-1)
    test_accuracy+=len(np.where(test_data_label.double()==(output_test.detach()>0.5).double())[0])
     #test_accuracy is total sum of correct prediction divided by total number of example, here we only do sum and down we do division 
    test_loss += criterion(output_valid,valid_data_label.float())
   
print("Test Accuracy: {:.3f}.. ".format( test_accuracy/316))    #total sum of correct/size of test dataset
# Out:
# Test Accuracy: 0.987..

# %%
checkpoint = {'input_size': 20,
              'output_size': 1,
              'hidden_layers': [64,256,256,64],
              'state_dict': model.state_dict()}

torch.save(checkpoint, 'checkpoint.pth')
